# %%
import pandas as pd
import seaborn as sns 

facebook = pd.read_csv('DATA/dataset_Facebook.csv', delimiter=";")

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
facebook['Post Hour']
# Out:
# 0       3
# 1      10
# 2       3
# 3      10
# 4       3
#        ..
# 495     2
# 496     8
# 497     2
# 498    11
# 499     4
# Name: Post Hour, Length: 500, dtype: int64

# %%
facebook.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
ax = sns.scatterplot (x = 'Post Hour', y = 'Lifetime Post Total Reach', data = facebook )

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
sns.set({'figure.figsize': (16,3)})
ax = sns.barplot (x = 'Post Hour', y = 'Lifetime Post Total Reach', data = facebook, ci = False, alette = 'coolwarm' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-48b067662d1e> in <module>
#       1 sns.set({'figure.figsize': (16,3)})
# ----> 2 ax = sns.barplot (x = 'Post Hour', y = 'Lifetime Post Total Reach', data = facebook, ci = False, alette = 'coolwarm' )
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3150         ax = plt.gca()
#    3151
# -> 3152     plotter.plot(ax, kwargs)
#    3153     return ax
#    3154
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1655     def plot(self, ax, bar_kws):
#    1656         """Make the plot."""
# -> 1657         self.draw_bars(ax, bar_kws)
#    1658         self.annotate_axes(ax)
# ...

# %%
sns.set(rc={'figure.figsize': (16,9)})

ax = sns.barplot (x = 'Post Hour', y = 'Lifetime Post Total Reach', data = facebook, ci = False, palette = 'coolwarm' )

# %%
ax = sns.barplot (x = 'Post Hour', y = 'share', data = facebook, ci = False )

# %%
ax = sns.barplot(x = 'Lifetime Post reach by people who like your Page', y = 'Type', color = '#C0A720', data = facebook, orient = 'h', ci = False, palette='coolwarm')

# %%
ax = sns.barplot (x = 'Post Hour', y = 'comment', data = facebook, ci = False )

# %%
ax = sns.scatterplot (x = 'Type', y = 'Lifetime Post Total Reach', data = facebook )

# %%
ax = sns.scatterplot (x = 'Category', y = 'Lifetime Post Total Reach', data = facebook )

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
ax = sns.scatterplot (x = 'Type', y = 'Lifetime Post Total Reach', data = facebook )

# %%
ax = sns.scatterplot (x = 'Page total likes', y = 'Total Interactions', data = facebook )
# means and then line is 1st and 3rd quartile

# %%
ax = sns.barplot (x = 'Post Weekday', y = 'like', data = facebook )

# %%
sns.set(rc={'figure.figsize': (12,9)})

ax = sns.barplot (x = 'Post Weekday', y = 'Total Interactions', data = facebook, ci = False, palette = 'coolwarm')

# %%
sns.set(rc={'figure.figsize': (12,9)})
ax = sns.barplot (x = 'Post Hour', y = 'Total Interactions', data = facebook, ci = False, palette = 'coolwarm' )

# %%
ax = sns.barplot (x = 'Post Month', y = 'Total Interactions', data = facebook, ci = False )

# %%
ax = sns.scatterplot (x = 'Paid', y = 'Total Interactions', data = facebook )

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize': (7,7)})

ax = sns.barplot (x = 'Paid', y = 'Total Interactions', data = facebook, ci = False, palette = 'coolwarm')

# %%
sns.set(rc={'figure.figsize': (5,4)})
ax = sns.barplot (x = 'Paid', y = 'like', data = facebook, ci = False, palette = 'coolwarm')

# %%
sns.set(rc={'figure.figsize': (5,4)})


ax = sns.barplot (x = 'Paid', y = 'share', data = facebook, ci = False, palette = 'coolwarm')

# %%
ax = sns.barplot (x = 'Paid', y = 'comment', data = facebook, ci = False, palette = 'coolwarm')

# %%
ax = sns.lineplot(x = 'like', y = 'share', data = facebook, hue = 'Paid')

# %%
ax = sns.barplot(x = 'Total Interactions', y = 'Page total likes', data = facebook)

# %%
sns.set(rc={'figure.figsize': (16,9)})
      
ax = sns.catplot("Paid", 
                 col = "Type", 
                 data = facebook, 
                 kind = "count",  
                 palette = 'coolwarm',  
                 aspect = .9,
                );

# %%
sns.set(rc={'figure.figsize': (16,9)})
ax = sns.catplot("Post Hour", 
                 col = "Type", 
                 data = facebook, 
                 kind = "count",  
                 palette = 'coolwarm',  
                 aspect = .9,
                );

# %%
sns.set(rc={'figure.figsize': (12,9)}) 
ax = sns.barplot(x = 'Total Interactions', y = 'Type', color = '#C0A720', data = facebook, orient = 'h', ci = False, palette='coolwarm')

# %%
ax = sns.catplot("Total Interactions", "Type",
                 col = "Paid", 
                 data = facebook, 
                 kind = "swarm",  
                 palette = 'cool',  
                 aspect = .9,
                );
